# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('alldata.csv', encoding = 'UTF-8')
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49276               2      Internet  RoundTrip             27               6
# 49277               1      Internet  RoundTrip            111               6
# 49278               1      Internet  RoundTrip             24               6
# 49279               1      Internet  RoundTrip             15               6
# 49280               1      Internet  RoundTrip             19               6
#
# ...

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay   flight_hour  \
# count    49281.000000   49281.000000    49281.000000  49281.000000
# mean         1.590187      84.723281       23.053976      9.070676
# std          1.016538      90.410229       33.832149      5.413099
# min          1.000000       0.000000        0.000000      0.000000
# 25%          1.000000      21.000000        5.000000      5.000000
# 50%          1.000000      51.000000       17.000000      9.000000
# 75%          2.000000     115.000000       28.000000     13.000000
# max          9.000000     867.000000      778.000000     23.000000
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# count         49281.000000          49281.000000           49281.000000
# mean              0.668229              0.295631               0.426635
# std               0.470854              0.456331               0.494593
# min               0.000000              0.000000               0.000000
# ...

# %%
plt.figure(figsize = (11,5))
#plt.plot()
plt.title(df.columns[-1])
pie = df['booking_complete'].value_counts().plot(kind = 'pie', autopct = '%.2f%%', explode = [0, 0.05])
pie
# Out:
# <Axes: title={'center': 'booking_complete'}, ylabel='count'>

# %%
booking = df['booking_complete'].value_counts().to_frame().to_csv(r"C:\Users\User\Python311_4\newclasswork\final_project\booking_rate.csv", index=True, sep=",")

# %%
df['booking_complete'].value_counts()
# Out:
# booking_complete
# 0    41890
# 1     7391
# Name: count, dtype: int64

# %%
booking = pd.read_csv('booking_rate.csv')
booking
# Out:
#    booking_complete  count
# 0                 0  41890
# 1                 1   7391

# %%
booking.iat[0, 0] = 'fail'
booking.iat[1, 0] = 'success'
booking
# Out:
#   booking_complete  count
# 0             fail  41890
# 1          success   7391

# %%
booking = booking.to_csv(r"C:\Users\User\Python311_4\newclasswork\final_project\booking_rate.csv", index=False, sep=",")

# %%
plt.figure(figsize = (3,5))
#plt.plot()
plt.title(df.columns[-1])
plt.bar(booking['booking_complete'], booking['count'], width = 0.2, align='center')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2 #plt.plot()
#       3 plt.title(df.columns[-1])
# ----> 4 plt.bar(booking['booking_complete'], booking['count'], width = 0.2, align='center')
#
# TypeError: 'NoneType' object is not subscriptable

# %%
t_col = ['sales_channel', 'trip_type','flight_day','route','booking_origin']
for col in t_col:
    print(f'value counts in {col} column')
    print(df[col].value_counts())
    print(' ')
# Out:
# value counts in sales_channel column
# sales_channel
# Internet    43917
# Mobile       5364
# Name: count, dtype: int64
#
# value counts in trip_type column
# trip_type
# RoundTrip     48779
# OneWay          386
# CircleTrip      116
# Name: count, dtype: int64
#
# value counts in flight_day column
# flight_day
# Mon    7988
# Wed    7562
# Tue    7558
# Thu    7323
# Fri    6685
# Sun    6442
# Sat    5723
# Name: count, dtype: int64
#
# value counts in route column
# route
# AKLKUL    2620
# PENTPE     912
# MELSGN     833
# ICNSIN     793
# DMKKIX     729
#           ...
# AKLHGH       1
# JEDPDG       1
# JEDPEN       1
# DACPEK       1
# MRUXIY       1
# Name: count, Length: 799, dtype: int64
#
# value counts in booking_origin column
# booking_origin
# Australia               17691
# Malaysia                 7055
# South Korea              4502
# Japan                    3819
# China                    3284
#                         ...
# Panama                      1
# ...

# %%
plt.figure(figsize = (20,5))
origin=df[col].value_counts()
origin.plot.bar()
# Out:
# <Axes: xlabel='booking_origin'>

# %%
channel=df['sales_channel'].value_counts()
channel.plot.bar()
# Out:
# <Axes: xlabel='sales_channel'>

# %%
ticket=df['trip_type'].value_counts()
ticket.plot.bar()
# Out:
# <Axes: xlabel='trip_type'>

# %%
days=df['flight_day'].value_counts()
days.plot.bar()
# Out:
# <Axes: xlabel='flight_day'>

# %%
palette1 = ['salmon','mediumseagreen']

# %%
plt.figure(figsize = (11,4))
plt.subplot(121)
sns.countplot(data = df, x = 'num_passengers', hue = 'booking_complete', palette = palette1)
plt.subplot(122)
sns.countplot(data = df, x = 'sales_channel', palette = palette1, hue = 'booking_complete')
plt.subplots_adjust(wspace=0.25)

# %%
plt.figure(figsize = (9,4))
sns.countplot(data = df, x ='flight_day', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='flight_day', ylabel='count'>

# %%
plt.figure(figsize = (9,4))
sns.countplot(data = df, x ='num_passengers', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='num_passengers', ylabel='count'>

# %%
plt.figure(figsize = (20,4))
sns.countplot(data = df, x ='flight_hour', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='flight_hour', ylabel='count'>

# %%
plt.figure(figsize = (9,4))
sns.countplot(data = df, x ='flight_duration', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='flight_duration', ylabel='count'>

# %%
df.columns
# Out:
# Index(['num_passengers', 'sales_channel', 'trip_type', 'purchase_lead',
#        'length_of_stay', 'flight_hour', 'flight_day', 'route',
#        'booking_origin', 'wants_extra_baggage', 'wants_preferred_seat',
#        'wants_in_flight_meals', 'flight_duration', 'booking_complete'],
#       dtype='object')

# %%
plt.figure(figsize = (10,4))
sns.countplot(data = df, x ='wants_extra_baggage', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='wants_extra_baggage', ylabel='count'>

# %%
plt.figure(figsize = (10,4))
sns.countplot(data = df, x ='wants_preferred_seat', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='wants_preferred_seat', ylabel='count'>

# %%
plt.figure(figsize = (10,4))
sns.countplot(data = df, x ='wants_in_flight_meals', hue = 'booking_complete', palette = palette1)
# Out:
# <Axes: xlabel='wants_in_flight_meals', ylabel='count'>
